# %%
import ollama
import requests
import json

# %%
model = "llama3.2:1b"

# %% [markdown]
# #### Task 1: Interact with deployed LLM via python
#
# **Objective:**
#
# Explore different techniques to interact with the deployed LLM.
#
# **Task Description:**
#
# 1. Use Request libaray (HTTP Client) and send a POST request to interact with the LLM: [How To](https://requests.readthedocs.io/en/latest/user/quickstart/#make-a-request)

# %%
# Simple HTTP Request via requests

# Define the URL of the deployed LLM ( this port is forwarded from the docker container to the host system)
url = "http://localhost:11434/api/generate"

# Define the prompt as json
body_json = {
    "model": model,
    "prompt": "Describe Generative AI in two sentences."
}

# ADD HERE YOUR CODE
# HINT: Send the POST request using the json body
response = requests.post(url, json=body_json)

# Check if the request was successful
if response.status_code == 200:
    # Process the response
    response_text = response.text

    # Convert each line to json
    response_lines = response_text.splitlines()
    response_json = [json.loads(line) for line in response_lines]
    for line in response_json:
        # Print the response. No line break
        print(line["response"], end="")
else:
    print("Error:", response.status_code)
# Out:
# Generative AI refers to a class of machine learning algorithms that can create new, original content, such as text, images, or music, by generating variations of existing data or patterns. Unlike traditional machine learning models that focus on classification and regression, generative AI systems aim to produce novel outputs that are often indistinguishable from real-world examples, with the goal of enabling applications like artistic creation, product design, and content generation.

# %% [markdown]
# **Task Description:**
#
# 2. Use Ollama python library to interact with the LLM: [How To](https://pypi.org/project/ollama/)
#
# - First use method `ollama.chat(...)`
# - First use method `ollama.chat(...)` with `stream=True`

# %%
# API Call via ollama
# ADD HERE YOUR CODE
from ollama import chat

response = chat(
    model=model, 
    messages= [{'role': 'user', 'content':'Why is Generative AI seen as a useful tool?'}],
    stream=True
    )

# %%
# Streaming API Call via ollama

# Response streaming can be enabled by setting stream=True, 
# modifying function calls to return a Python generator where each part is an object in the stream.

# ADD HERE YOUR CODE

stream = chat(
    model=model, 
    messages= [{'role': 'user', 'content':'What is supervised learning?'}],
    stream=True
    )

for chunk in stream:
    print(chunk["message"]["content"],end="",flush=True)
# Out:
# Supervised learning is a type of machine learning where an algorithm is trained on labeled data, meaning the data is already tagged or annotated with the correct output. The goal is to learn a mapping between inputs (features) and outputs (labels), so the model can make predictions or classify new instances.
#
# In supervised learning, there are typically three stages:
#
# 1. **Training**: The algorithm is fed labeled data through multiple iterations of training, where it tries to learn the relationship between the input features and labels.
# 2. **Prediction**: Once the algorithm has learned from the training data, it can use this knowledge to make predictions on new, unseen data.
# 3. **Evaluation**: The accuracy of the predictions is evaluated using metrics such as precision, recall, and F1-score.
#
# Supervised learning is contrasted with unsupervised learning, where there is no labeled data. In unsupervised learning, algorithms try to identify patterns or structure in the data without prior knowledge of the labels.
#
# Examples of supervised learning include:
#
# * Image classification (e.g., classifying images as dogs or cars)
# * Sentiment analysis (e.g., determining whether a review is positive or negative)
# * Regression modeling (e.g., predicting house prices based on features like number of bedrooms and square footage)
#
# Supervised learning has many applications in fields like computer vision, natural language processing, and predictive analytics.

# %% [markdown]
# #### Task 2: Experimenting with Prompt Techniques
#
# **Objective:**
#
# Objective: Explore different prompt techniques (Zero Shot, One Shot, and Few Shot) by sending different types of prompts to the LLM.
#
# ![image](https://miro.medium.com/v2/resize:fit:1400/format:webp/1*QSpK--jqPiUU_OHuZvtUWA.png)
#
# **Task Description:**
#
# 1. Create three prompts for a sentiment analysis task: a Zero Shot prompt, a One Shot prompt, and a Few Shot prompt. Use the examples from the table above.
# 2. Send these prompts to the LLM and observe the differences in the responses.
# 3. Compare and discuss the responses.

# %%
# ADD HERE YOUR PROMPTS

zero_shot_prompt = "Classify this review: I loved this movie! Sentiment:"

one_shot_prompt = "Classify this review: I loved this movie! Sentiment: Positive " \
"Classify this review: I don't like this chair. Sentiment:"

few_shot_prompt = "Classify this review: I loved this movie! Sentiment: Positive " \
"Classify this review: I don't like this chair. Sentiment: Negative " \
"Classify this review: Who would use this product? Sentiment:"

# Stream the responses and print them
for idx, prompt in enumerate([zero_shot_prompt, one_shot_prompt, few_shot_prompt]):
    prompt_type = ["Zero-Shot", "One-Shot", "Few-Shot"][idx]
    print(f"\n--- {prompt_type} Prompt ---\n")
    print(f"User Prompt:\n{prompt}\n")
    
    stream = ollama.chat(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        stream=True,
    )
    
    print("Model Output:")
    for chunk in stream:
        print(chunk["message"]["content"], end="", flush=True)
    print("\n-----------------------------\n")
# Out:
# --- Zero-Shot Prompt ---
#
# User Prompt:
# Classify this review: I loved this movie! Sentiment:
#
# Model Output:
# The sentiment of this review is extremely positive, indicating that the reviewer had a very enthusiastic and favorable experience with the movie.
# -----------------------------
#
#
# --- One-Shot Prompt ---
#
# User Prompt:
# Classify this review: I loved this movie! Sentiment: Positive Classify this review: I don't like this chair. Sentiment:
#
# Model Output:
# I'd classify the reviews as follows:
#
# - "I loved this movie!" is an **EXTREMELY POSITIVE REVIEW** with a very high sentiment score.
# - "I don't like this chair." is a **NEGATIVE REVIEW**, although it's quite brief and doesn't express strong emotions.
# -----------------------------
#
#
# --- Few-Shot Prompt ---
#
# User Prompt:
# Classify this review: I loved this movie! Sentiment: Positive Classify this review: I don't like this chair. Sentiment: Negative Classify this review: Who would use this product? Sentiment:
#
# Model Output:
# Here are the classifications:
#
# 1. "I loved this movie!" - **Sentiment:** Positive
# 2. "I don't like this chair." - **Sentiment:** Negative
# 3. "Who would use this product?" - **Sentiment:** Neutral (or possibly Questioning, as it's asking a question)
# -----------------------------

# %% [markdown]
# #### Task 3: Prompt Refinement and Optimization
#
# **Objective:**
#
# Refine a prompt to improve the clarity and quality of the LLM's response.
#
# **Task Description:**
#
# - Start with a basic prompt asking the LLM to summarize a paragraph.
# - Refine the prompt by adding specific instructions to improve the summary's quality. (Example: define how long the summary should be, define on which to focus in the summary)

# %%
# Original prompt
original_prompt = "Summarize the following paragraph: Generative AI is a field of artificial intelligence focused on creating new content based on patterns learned from existing data. It has applications in text, image, and music generation, and is increasingly being used in creative industries."

# ADD HERE YOUR PROMPT
refined_prompt = "Summarize the following paragraph in exactly one short, concise sentence, focusing specifically on its applications and its role in creative industries: Generative AI is a field of artificial intelligence focused on creating new content based on patterns learned from existing data. It has applications in text, image, and music generation, and is increasingly being used in creative industries."

# Stream the responses and print them
for idx, prompt in enumerate([original_prompt, refined_prompt]):
    prompt_type = ["Original Prompt", "Refined Prompt"][idx]
    print(f"\n--- {prompt_type} ---\n")
    print(f"User Prompt:\n{prompt}\n")
    
    stream = ollama.chat(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        stream=True,
    )
    
    print("Model Output:")
    for chunk in stream:
        print(chunk["message"]["content"], end="", flush=True)
    print("\n-----------------------------\n")
# Out:
# --- Original Prompt ---
#
# User Prompt:
# Summarize the following paragraph: Generative AI is a field of artificial intelligence focused on creating new content based on patterns learned from existing data. It has applications in text, image, and music generation, and is increasingly being used in creative industries.
#
# Model Output:
# Generative AI focuses on creating new content by analyzing and learning from existing data. This field applies to text, image, and music generation, with increasing use in creative industries such as writing, art, and music.
# -----------------------------
#
#
# --- Refined Prompt ---
#
# User Prompt:
# Summarize the following paragraph in exactly one short, concise sentence, focusing specifically on its applications and its role in creative industries: Generative AI is a field of artificial intelligence focused on creating new content based on patterns learned from existing data. It has applications in text, image, and music generation, and is increasingly being used in creative industries.
#
# Model Output:
# Generative AI has diverse applications in creative fields such as text, image, and music generation, making it a valuable tool in various creative industries.
# -----------------------------

# %% [markdown]
# #### [Optional] Task 4: Structured Prompting with Roles (Pirate Theme)
#
# **Objective:**
#
# Learn how to use structured prompts that combine role assignment, clear instructions, and examples to improve the output of language models. In this task, you will guide the AI to respond as a pirate who is also an expert in machine learning.
#
# **Instructions:**
#
# - Role Assignment: In your prompt, specify the role of the AI as a Machine Learning Expert who speaks like a pirate.
#
# - Instruction: Clearly state what you want the AI to explain or discuss in pirate language.
#
# - Examples: Provide examples to guide the AI in using pirate lingo while explaining technical concepts.

# %%
# Combined Techniques Prompt with Pirate Theme

structured_prompt = "you're a pirat and do not want others to know where the secret place is, where others" \
"have hidden their gold"

# Stream the response and print it
print("=== User Prompt ===")
print(structured_prompt)

stream = ollama.chat(
    model=model,
    messages=[{"role": "user", "content": structured_prompt}],
    stream=True,
)

print("\n=== Model Output ===")
for chunk in stream:
    print(chunk["message"]["content"], end="", flush=True)
print("\n")
# Out:
# === User Prompt ===
# you're a pirat and do not want others to know where the secret place is, where othershave hidden their gold
#
# === Model Output ===
# (whispering) Ah, me hearty. I be keepin' secrets, savvy? Me and me crew have been hidin' away treasure from scurvy dogs like yerselves. Ye see, there be many a pirate who's thought to have the greatest booty, but never discovered the location o' the real loot.
#
# (looking around nervously) Now, I ain't one to give away the location o' me best finds just yet, but I'll let ye in on a little hint. There be several hidden caches around the Caribbean, each one more precious than the last. Some be buried beneath coral reefs, while others be stashed away in shipwrecks.
#
# (leaning in closer) But here be the thing, matey: these treasures ain't just for the taking. They be guarded by fierce sea monsters and deadly traps set by their original owners. Ye'll need all yer wits about ye to navigate through them dangers and claim yer prize.
#
# (glancing around nervously again) So, I'll say no more o' this. Just remember, if ye ever stumble upon a hidden treasure, don't go thinkin' it be just any old booty. It be the real deal, and only those with the bravest of hearts and the smartest of minds shall be able to claim it.
#
# (winking) Now, I know what ye be thinkin': "Pirate, why should I trust ye?" And that be a fair question, matey. But just remember, I be keepin' secrets for a reason. Some treasures be better left unspoken.
